# %% [markdown]
# # Flow Predictor with MLflow Integration
#
# This notebook implements MLflow tracking for the flow predictor model with child runs for each epoch.

# %%
# Import section - same as before
import keras
from keras.models import Model
from keras import backend as K
from keras.layers import (
    Input, 
    concatenate, 
    Conv2D,
    MaxPooling2D,
    Conv2DTranspose,
    ZeroPadding2D
)
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Reshape, Dense, Flatten
from tensorflow.keras.callbacks import Callback

import vtk
from vtm_data import VTK_data
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import os
import mlflow
import mlflow.keras

# Create experiment
mlflow.set_experiment("Flow_Predictor_Training")

# Enable MLflow autologging
mlflow.keras.autolog(
    log_models=True,
    log_model_signatures=True,
    log_input_examples=True,
    registered_model_name="flow_predictor"
)
# Out:
# 2025-01-15 17:47:47.424602: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736963267.440013   16084 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736963267.444616   16084 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-15 17:47:47.459771: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025/01/15 17:47:51 WARNING mlflow.utils.autologging_utils: MLflow keras autologging is known to be compatible with 3.0.2 <= keras <= 3.6.0, but the installed version is 3.8.0. If you encounter errors during autologging, try upgrading / downgrading keras to a compatible version, or try upgrading MLflow.

# %%
# Training parameters
batch_size = 32
epochs = 3

# %%
# load dataset
class VTK_data:
    def __init__(self, base_path, split_ratio=0.8):
        self.base_path = Path(base_path)
        self.data = []
        self.geometries = []
        self.steady_flows = []
        self.split_ratio = split_ratio
        self.split_line = 0
        
    def load_data(self):
        for dirpath, dirnames, filenames in os.walk(self.base_path):
            for filename in filenames:
                if filename.endswith('.vtm'):
                    full_path = Path(dirpath) / filename
                    try:
                        data = self._load_single_file(full_path)
                        if data is not None:
                            print(f"\nProcessing file: {filename}")
                            print(f"Full path: {full_path}")
                            
                            if 'geometry' in filename:
                                print(f"Classified as geometry file")
                                self.geometries.append(data)
                            elif 'cylinder2d_iT' in filename:
                                print(f"Classified as flow file")
                                self.steady_flows.append(data)
                            else:
                                print(f"Skipping file: {filename}")
                    except Exception as e:
                        print(f"Error loading {full_path}: {str(e)}")
        
        print("\nLoaded data summary:")
        print(f"Number of geometry files: {len(self.geometries)}")
        if self.geometries:
            print(f"Shape of first geometry: {np.array(self.geometries[0]).shape}")
        
        print(f"Number of flow files: {len(self.steady_flows)}")
        if self.steady_flows:
            print(f"Shape of first flow: {np.array(self.steady_flows[0]).shape}")
        
        total_samples = len(self.geometries)
        self.split_line = int(total_samples * self.split_ratio)
        
        return self.geometries, self.steady_flows
    
    def _load_single_file(self, file_path):
        reader = vtk.vtkXMLMultiBlockDataReader()
        reader.SetFileName(str(file_path))
        reader.Update()
        
        if reader.GetErrorCode() != 0:
            raise RuntimeError(f"Error reading file")
        
        data = reader.GetOutput()
        if data is None:
            raise RuntimeError("No data read from file")
            
        data_iterator = data.NewIterator()
        img_data = data_iterator.GetCurrentDataObject()
        
        if img_data is None:
            raise RuntimeError("No image data found in file")
        
        if hasattr(img_data, 'GetProducerPort'):
            producer = img_data.GetProducerPort()
            if producer:
                producer.Update()
        elif hasattr(img_data, 'GetSource'):
            source = img_data.GetSource()
            if source:
                source.Update()
                
        point_data = img_data.GetPointData()
        array_data = point_data.GetArray(0)
        array_data = vtk.util.numpy_support.vtk_to_numpy(array_data)
        
        return array_data

# Create instance and load data
base_directory = "/mnt/data/cfd-ml-examples/sumulation"
dataset = VTK_data(base_directory)

# Load the data
geometries, steady_flows = dataset.load_data()
# Out:
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_
vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01024/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01024/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0027526.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01024/vtkData/data/cylinder2d_iT0027526.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01025/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01025/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01025/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0027269.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01025/vtkData/data/cylinder2d_iT0027269.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01026/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01026/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01026/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0025671.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01026/vtkData/data/cylinder2d_iT0025671.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01027/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01027/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01027/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0023046.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01027/vtkData/data/cylinder2d_iT0023046.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01028/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01028/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01028/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0029031.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01028/vtkData/data/cylinder2d_iT0029031.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01029/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01029/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01029/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0025719.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01029/vtkData/data/cylinder2d_iT0025719.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01030/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01030/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01030/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0025679.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01030/vtkData/data/cylinder2d_iT0025679.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01031/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01031/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01031/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0024984.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01031/vtkData/data/cylinder2d_iT0024984.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01032/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01032/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01032/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0026261.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01032/vtkData/data/cylinder2d_iT0026261.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01033/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01033/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01033/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0028178.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01033/vtkData/data/cylinder2d_iT0028178.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01034/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01034/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01034/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0023092.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01034/vtkData/data/cylinder2d_iT0023092.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01035/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01035/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01035/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0024692.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01035/vtkData/data/cylinder2d_iT0024692.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01036/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01036/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01036/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0028504.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01036/vtkData/data/cylinder2d_iT0028504.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01037/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01037/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01037/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0029105.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01037/vtkData/data/cylinder2d_iT0029105.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01038/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01038/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01038/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0023536.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01038/vtkData/data/cylinder2d_iT0023536.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01039/vtkData/geometry_iT0000000.vtm
# Classified as geometry file
#
# Processing file: cuboid_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01039/vtkData/cuboid_iT0000000.vtm
# Skipping file: cuboid_iT0000000.vtm
#
# Processing file: rank_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01039/vtkData/rank_iT0000000.vtm
# Skipping file: rank_iT0000000.vtm
#
# Processing file: cylinder2d_iT0026408.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01039/vtkData/data/cylinder2d_iT0026408.vtm
# Classified as flow file
#
# Processing file: geometry_iT0000000.vtm
# Full path: /mnt/data/cfd-ml-examples/sumulation/simulation_data/runlog_01040/vtkData/geometry_iT0000000.vtm
# Classified as geometry file

# %%
# Data split - same as before
train_geometries = dataset.geometries[0:dataset.split_line]
train_steady_flows = dataset.steady_flows[0:dataset.split_line]
test_geometries = dataset.geometries[dataset.split_line:-1]
test_steady_flows = dataset.steady_flows[dataset.split_line:-1]

# %%
# Data reshaping - same as before
train_geometries = np.stack(train_geometries, axis=0)
train_steady_flows = np.stack(train_steady_flows, axis=0)
test_geometries = np.stack(test_geometries, axis=0)
test_steady_flows = np.stack(test_steady_flows, axis=0)

# %%
# Model definition - same as before
def create_flow_predictor_model():
    # Model architecture implementation same as before...
    return model

# Create model
model = create_flow_predictor_model()
model.summary()

# %%
# Import all necessary layers
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Reshape, Dense, Flatten, concatenate, Conv2DTranspose, ZeroPadding2D

# Define input layer to match your geometry data shape
inputs = Input(shape=(9812,))

# Initial reshape to work with convolutions
# We reshape to (44, 223, 1) for processing
reshaped = Reshape((44, 223, 1))(inputs)

# Encoder Path (Downsampling)
# First block
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(reshaped)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

# Second block
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

# Third block
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

# Fourth block
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

# Bridge
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

# Decoder Path (Upsampling)
# First upsampling block
up6 = concatenate([ZeroPadding2D(((1,0),(1,0)))(Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5)), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

# Second upsampling block
up7 = concatenate([ZeroPadding2D(((1,0),(1,0)))(Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6)), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

# Third upsampling block
up8 = concatenate([ZeroPadding2D(((0,0),(1,0)))(Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7)), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

# Fourth upsampling block
up9 = concatenate([ZeroPadding2D(((0,0),(1,0)))(Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8)), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

# Convolutional output before reshaping
conv10 = Conv2D(2, (1, 1), activation='linear')(conv9)

# Final reshape to match your target shape
final_output = Reshape((9812, 2))(conv10)

# Create the model with the correct output shape
model = Model(inputs=inputs, outputs=final_output)

# Compile the model
model.compile(
    loss='mse',
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=['MSE']
)

# %%
# Custom callback for epoch-level MLflow tracking
class MLflowEpochCallback(Callback):
    def __init__(self, parent_run_id):
        super().__init__()
        self.parent_run_id = parent_run_id
    
    def on_epoch_begin(self, epoch, logs=None):
        mlflow.start_run(run_name=f"epoch_{epoch}", nested=True)
    
    def on_epoch_end(self, epoch, logs=None):
        if logs:
            for metric_name, metric_value in logs.items():
                mlflow.log_metric(metric_name, metric_value)
            mlflow.log_metric("epoch", epoch)
        mlflow.end_run()

print("Starting MLflow run for model training...")

# Train model with MLflow tracking and epoch-level child runs
with mlflow.start_run(run_name="flow_predictor_training") as parent_run:
    # Log parameters
    mlflow.log_param("batch_size", batch_size)
    mlflow.log_param("epochs", epochs)
    mlflow.log_param("learning_rate", 1e-4)
    mlflow.log_param("train_samples", len(train_geometries))
    mlflow.log_param("test_samples", len(test_geometries))
    
    # Create epoch callback
    epoch_callback = MLflowEpochCallback(parent_run.info.run_id)
    
    # Train model
    history = model.fit(
        train_geometries, 
        train_steady_flows,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        validation_data=(test_geometries, test_steady_flows),
        callbacks=[epoch_callback]
    )
    
    # Evaluate on test set
    test_loss = model.evaluate(test_geometries, test_steady_flows, verbose=0)
    mlflow.log_metric("test_mse", test_loss[0])
    
    # Generate and log prediction visualizations
    predicted_steady_flow = model.predict(test_geometries[:3], batch_size=batch_size)
    
    for i in range(3):
        pred_reshaped = predicted_steady_flow[i].reshape(44, 223, 2)
        true_reshaped = test_steady_flows[i].reshape(44, 223, 2)
        geom_reshaped = test_geometries[i].reshape(44, 223)
        
        plt.figure(figsize=(15, 5))
        velocity_image = np.concatenate([
            pred_reshaped[:,:,0],
            true_reshaped[:,:,0],
            geom_reshaped/10.0
        ], axis=1)
        
        plt.imshow(velocity_image)
        plt.title(f'Sample {i+1}: Predicted vs True Flow vs Geometry')
        plt.colorbar()
        plt.savefig(f'prediction_sample_{i}.png')
        mlflow.log_artifact(f'prediction_sample_{i}.png')
        plt.close()
    
    # Check if best model and register if appropriate
    client = mlflow.tracking.MlflowClient()
    runs = client.search_runs(
        experiment_ids=[parent_run.info.experiment_id],
        order_by=["metrics.test_mse ASC"]
    )
    
    if parent_run.info.run_id == runs[0].info.run_id:
        print("New best model found! Registering model...")
        mlflow.keras.log_model(
            model,
            "model",
            registered_model_name="flow_predictor",
            signature=mlflow.models.infer_signature(
                train_geometries[:2],
                model.predict(train_geometries[:2])
            )
        )
        print("Model registered successfully!")
    else:
        print("Not best model - skipping registration")

print('Training and logging complete!')
